# %% [markdown]
# # 0. Loading all Data

# %%
# %reload_ext autoreload
# %autoreload 2
from B_model import *
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import copy
from tensorflow import keras

all_metrics_df,testParamDf = data_generation()
# Out:
# Init Plugin
# Init Graph Optimizer
# Init Kernel
# Unique DODs 18
# Unique discharging_protocol 23
# Unique charging_protocol 47
# 8
# 12
# 5

# %% [markdown]
# # Result Selection # =====# Result Selection # =====# Result Selection # =====# Result Selection # =====

# %%
result_all = pd.read_csv('result.csv')
result_all = result_all.loc[result_all['error'] != 0]
result_all_selected = result_all.loc[result_all['error'] < 1000]
result_all.shape,result_all_selected.shape
# Out:
# ((4320, 8), (3138, 8))

# %%
result_all_selected
# Out:
#       Unnamed: 0  argu loss_fun                          class_weight  \
# 0              0   1.0      mse              {0: 1.0, 1: 1.0, 2: 1.0}
# 1              1   1.0      mse              {0: 1.0, 1: 1.0, 2: 1.0}
# 2              2   1.0      mse              {0: 1.0, 1: 1.0, 2: 1.0}
# 3              3   1.0      mse              {0: 1.0, 1: 1.0, 2: 1.0}
# 4              4   1.0      mse              {0: 1.0, 1: 1.0, 2: 1.0}
# ...          ...   ...      ...                                   ...
# 4315        4315   4.0      mae  {0: 100000000.0, 1: 10000.0, 2: 1.0}
# 4316        4316   4.0      mae  {0: 100000000.0, 1: 10000.0, 2: 1.0}
# 4317        4317   4.0      mae  {0: 100000000.0, 1: 10000.0, 2: 1.0}
# 4318        4318   4.0      mae  {0: 100000000.0, 1: 10000.0, 2: 1.0}
# 4319        4319   4.0      mae  {0: 100000000.0, 1: 10000.0, 2: 1.0}
#
#             nl      opt  epochs       error
# 0     [30, 10]      SGD   100.0  591.884646
# 1     [30, 10]      SGD   200.0  566.150001
# 2     [30, 10]      SGD   300.0  496.044002
# 3     [30, 10]     Adam   100.0  410.303547
# 4     [30, 10]     Adam   200.0  336.877759
# ...        ...      ...     ...         ...
# 4315  [90, 70]     Adam   200.0  189.592158
# 4316  [90, 70]     Adam   300.0  238.871153
# 4317  [90, 70]  RMSprop   100.0  444.198762
# 4318  [90, 70]  RMSprop   200.0  395.259875
# 4319  [90, 70]  RMSprop   300.0  279.117762
#
# [3138 rows x 8 columns]

# %% [markdown]
# # Plotting

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
#group by argu + opt and show the mean or median or the error
def plot_tune_result(arg1,arg2,error):
    output = result_all_selected.groupby([arg1,arg2])['error'].aggregate([np.mean,np.median]).reset_index()

    ax = sns.lineplot(x = arg1, y = error, 
                data = output, 
                hue= arg2,)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
    ax.set(xlabel='{}'.format(arg1), ylabel='Mean Absolute Error by Curve')
    plt.show()

# %%
plot_tune_result('argu','opt','median')

# %%
plot_tune_result('argu','class_weight','median')

# %%
plot_tune_result('argu','loss_fun','median')

# %%
plot_tune_result('argu','nl','median')

# %%
plot_tune_result('argu','epochs','median')

# %%
def plot_tune_result_3(arg1,arg2,arg3):
    output = result_all_selected.groupby([arg1,arg2,arg3])['error'].aggregate([np.mean,np.median]).reset_index()
    
    #palette = sns.color_palette("rocket_r",n_color = )
    # Plot the lines on two facets
    ax = sns.relplot(
            data=output,
            x= arg1, y= 'mean',
            hue= arg2, col= arg3,
            kind="line",
            height=10, aspect=.75, facet_kws=dict(sharex=False),
    )
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
    ax.set(xlabel='{}'.format(arg1), ylabel='Mean Absolute Error by Curve')
    plt.show()

# %%
plot_tune_result_3('argu','class_weight','epochs')
# Out:
# No handles with labels found to put in legend.

# %%
plot_tune_result_3('argu','class_weight','loss_fun')
# Out:
# No handles with labels found to put in legend.

# %%
top_30 = result_all.sorta_values(by = ['error'])[0:30].index

# %%
top_30
# Out:
# Int64Index([3881, 3780, 3872, 3834, 3789, 3843, 3827, 3863, 3835, 3809, 3825,
#             4100, 3845, 3562, 1022, 2048, 3791, 3871,  715,  724,  287,  167,
#              430,  984,  779,  859, 3907, 3880,  770, 3861],
#            dtype='int64')

# %% [markdown]
# # Result Selection # =====# Result Selection # =====# Result Selection # =====# Result Selection # =====

# %% [markdown]
# # 1. Data Preparation

# %%
# 2nd Order Raw only!
test_coef = ["0","2","3","4","exponential"]
func_coef = ["raw","second","third","forth","exponential"]
for i in range(0,1):
    globals()[f'X{test_coef[i]}'],globals()[f'y{test_coef[i]}'],globals()[f'Y{test_coef[i]}'],globals()[f'X_Y_merged{test_coef[i]}'] = \
        eval(func_coef[i]+"_order_poly_fitting(all_metrics_df,testParamDf)")

# %% [markdown]
# ## 1.1 Choose a Data Version

# %%
version = '0' #raw ones
X,y,Y,X_Y_merged = eval('X'+version),eval('y'+version),eval('Y'+version),eval('X_Y_merged'+version)
objective = eval('objective_'+version)

# %% [markdown]
# ## 1.2 Models Construction

# %%
model_raw = battery_model(0,X,y,Y,X_Y_merged,objective)

# %% [markdown]
# ## 1.3 Data Argumentation

# %% [markdown]
# ### (Reset)

# %% [markdown]
# # 2. Training

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ```python
# index = 0
# for i0 in argu_all:
#     model_raw_copy1 = copy.deepcopy(model_raw)
#     model_raw_copy1.input_argumentation_update(i0)
#     model_raw_copy2 = copy.deepcopy(model_raw_copy1)
#     for i1 in loss_fun_all:
#         for i2 in class_weight_all:
#             for i3 in nl_all:
#                 for i4 in opt_all:
#                     for i5 in epochs_all:
#                         model_raw_copy = copy.deepcopy(model_raw_copy2)
#                         result['argu'][index] = i0
#                         result['loss_fun'][index] = i1
#                         result['class_weight'][index] = "{}".format(i2)
#                         result['nl'][index] = "{}".format(i3)
#                         result['opt'][index] = i4
#                         result['epochs'][index] = i5
#                         result['error'][index] = model_raw_copy.model_construction_and_training(all_metrics_df,i1,i2,i3,i4,i5,0)
#                         index+=1
#                         print (i0,i1,i2,i3,i4,i5)
# ```

# %% [markdown]
# # Result

# %%
#argu	loss_fun	class_weight	nl	opt	epochs	
i = 3881
i0 = int(result_all['argu'][i])
i1 = result_all['loss_fun'][i]
i2 =eval(result_all['class_weight'][i])

i3 = eval(result_all['nl'][i])

i4 = result_all['opt'][i]
i5 = int(result_all['epochs'][i])

# %%
model_raw_copy = copy.deepcopy(model_raw)

# %%
records = []
for i in top_30:
    i0 = int(result_all['argu'][i])
    i1 = result_all['loss_fun'][i]
    i2 =eval(result_all['class_weight'][i])
    i3 = eval(result_all['nl'][i])
    i4 = result_all['opt'][i]
    i5 = int(result_all['epochs'][i])
    
    model_raw_copy1 = copy.deepcopy(model_raw_copy)
    model_raw_copy1.input_argumentation_update(i0)
    model_raw_copy2 = copy.deepcopy(model_raw_copy1)
    records.append(model_raw_copy2.model_construction_and_training(all_metrics_df,i1,i2,i3,i4,i5,0))
# Out:
# 2021-11-24 03:31:39.019986: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:31:39.156386: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:31:53.849125: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:31:53.976765: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:31:54.091651: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:31:58.640705: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:31:58.767314: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:31:58.883650: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:32:13.402129: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:32:13.536367: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:32:13.656850: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:32:18.400833: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:32:18.533543: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:32:18.651942: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:32:23.500512: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:32:23.624640: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:32:23.740640: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:32:28.185789: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:32:28.308188: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:32:28.419865: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:32:42.124322: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:32:42.246848: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:32:42.359394: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:32:56.015239: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:32:56.139366: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:32:56.251692: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:33:05.475473: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:33:05.599390: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:33:05.710722: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:33:19.361399: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:33:19.486737: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:33:19.850266: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:33:24.439859: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:33:24.576189: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:33:24.692612: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:33:38.964040: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:33:39.097650: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:33:39.210267: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:33:52.711892: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:33:52.868465: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:33:53.010098: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:34:04.413578: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:34:04.550031: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:34:04.666562: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:34:18.594547: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:34:18.731560: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:34:18.848040: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:34:32.730919: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:34:32.853915: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:34:32.967103: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:34:46.256268: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:34:46.379212: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:34:46.492271: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:34:55.746526: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:34:55.882428: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:34:55.999897: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:35:05.238756: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:35:05.375838: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:35:05.491767: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:35:14.743905: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:35:15.152646: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:35:15.293168: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:35:31.738444: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:35:31.872774: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:35:31.989443: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:35:45.786093: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:35:45.942893: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:35:46.085660: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:35:57.590718: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:35:57.732447: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:35:57.855581: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:36:02.634928: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:36:02.776365: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:36:02.899134: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:36:17.794064: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:36:17.934274: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:36:18.055945: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:36:27.685251: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:36:27.813256: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:36:27.932952: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:36:38.281147: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:36:38.408303: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:36:38.526359: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:36:48.182046: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:36:48.324351: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:36:48.446453: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:37:03.191173: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:37:03.319202: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:37:03.433938: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 03:37:08.047748: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
records_array = np.array(records)
select = top_30[np.argsort(records_array) == 10][0]
display(result_all.loc[2048])
#859 - Good
#770 not bad
#3825 overfitting / underfitting???
# 3881 -> WHen input dimension high (4) -> Hard to differeate those value -> tend to predict the same
# reject 4 dimension argument
# Out:
# Unnamed: 0                                      2048
# argu                                             2.0
# loss_fun                                         mae
# class_weight    {0: 100000000.0, 1: 10000.0, 2: 1.0}
# nl                                  [70, 50, 30, 10]
# opt                                             Adam
# epochs                                         300.0
# error                                      70.526142
# Name: 2048, dtype: object
# 2021-11-24 11:18:05.218091: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 11:18:05.447863: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 11:18:25.142240: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 216.33146565659862

# %%
i0 = 1
i1 = 'mae'
i2 = {0: 100000000.0, 1: 10000.0, 2: 1.0}
i3 = [80,30,10]
i4 = 'RMSprop'
i5 = 300
model_raw_copy1 = copy.deepcopy(model_raw_copy)
model_raw_copy1.input_argumentation_update(i0)
model_raw_copy2 = copy.deepcopy(model_raw_copy1)
model_raw_copy2.model_construction_and_training(all_metrics_df,i1,i2,i3,i4,i5,0)
# Out:
# 2021-11-24 19:42:55.272303: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 19:42:55.420893: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-24 19:43:23.039776: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 146.89573353552504

# %%
model_raw_copy2.plot_curve("test",all_metrics_df,1000,2.5)

# %%
model_raw_copy2.plot_curve("test_true",all_metrics_df,1000,2.5)
