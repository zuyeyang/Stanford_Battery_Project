# %% [markdown]
# # 0. Loading all Data

# %%
# %reload_ext autoreload
# %autoreload 2
from B_model import *
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import copy
from tensorflow import keras
import os
import glob
import pandas as pd

all_metrics_df,testParamDf = data_generation()
# Out:
# Unique DODs 18
# Unique discharging_protocol 23
# Unique charging_protocol 47
# 8
# 12
# 5

# %% [markdown]
# # Result Selection # =====# Result Selection # =====# Result Selection # =====# Result Selection # =====

# %%
result_all = pd.read_csv('final_result.csv',index_col =0)
result_all
# Out:
#      argu loss_fun        class_weight                 nl      opt  epochs  \
# 0     3.0      mae  {0: 6, 1: 1, 2: 1}           [40, 10]  RMSprop   150.0
# 1     3.0      mae  {0: 6, 1: 1, 2: 1}           [40, 10]  RMSprop   300.0
# 2     3.0      mae  {0: 6, 1: 1, 2: 1}       [70, 40, 10]  RMSprop   150.0
# 3     3.0      mae  {0: 6, 1: 1, 2: 1}       [70, 40, 10]  RMSprop   300.0
# 4     3.0      mae  {0: 6, 1: 1, 2: 1}  [100, 70, 40, 10]  RMSprop   150.0
# ..    ...      ...                 ...                ...      ...     ...
# 435   3.0      mse  {0: 8, 1: 3, 2: 1}          [100, 40]  RMSprop   300.0
# 436   3.0      mse  {0: 8, 1: 3, 2: 1}          [100, 70]     Adam   150.0
# 437   3.0      mse  {0: 8, 1: 3, 2: 1}          [100, 70]     Adam   300.0
# 438   3.0      mse  {0: 8, 1: 3, 2: 1}          [100, 70]  RMSprop   150.0
# 439   3.0      mse  {0: 8, 1: 3, 2: 1}          [100, 70]  RMSprop   300.0
#
#      Rsquare_median  R_greater_80  R_greater_85
# 0          0.381377      0.159091      0.136364
# 1          0.374362      0.340909      0.295455
# 2          0.640376      0.386364      0.340909
# 3          0.624640      0.340909      0.295455
# 4          0.705252      0.431818      0.431818
# ..              ...           ...           ...
# 435        0.145900      0.272727      0.227273
# 436       -0.329366      0.250000      0.204545
# 437       -0.125726      0.295455      0.227273
# 438       -0.304108      0.295455      0.250000
# 439        0.327325      0.272727      0.227273
#
# [2376 rows x 9 columns]

# %%
result_all.sort_values('Rsquare_median',ascending=False)[0:10]
# Out:
#       argu loss_fun        class_weight             nl      opt  epochs  \
# 1596   2.0      mae  {0: 6, 1: 1, 2: 1}  [100, 40, 10]     Adam   150.0
# 544    1.0      mae  {0: 2, 1: 1, 2: 1}       [70, 10]     Adam   150.0
# 722    1.0      mae  {0: 6, 1: 1, 2: 1}       [70, 10]  RMSprop   150.0
# 1598   2.0      mae  {0: 6, 1: 1, 2: 1}  [100, 40, 10]  RMSprop   150.0
# 1341   2.0      mae  {0: 1, 1: 1, 2: 1}  [100, 70, 10]     Adam   300.0
# 814    1.0      mae  {0: 8, 1: 1, 2: 1}  [100, 70, 10]  RMSprop   150.0
# 731    1.0      mae  {0: 6, 1: 1, 2: 1}      [100, 10]  RMSprop   300.0
# 834    1.0      mae  {0: 8, 1: 1, 2: 1}      [100, 70]  RMSprop   150.0
# 643    1.0      mae  {0: 4, 1: 1, 2: 1}      [100, 10]  RMSprop   300.0
# 1687   2.0      mae  {0: 8, 1: 1, 2: 1}  [100, 40, 10]  RMSprop   300.0
#
#       Rsquare_median  R_greater_80  R_greater_85
# 1596        0.886946      0.568182      0.522727
# 544         0.885328      0.568182      0.522727
# 722         0.883748      0.590909      0.545455
# 1598        0.879487      0.522727      0.522727
# 1341        0.871632      0.545455      0.545455
# 814         0.868501      0.522727      0.522727
# 731         0.868265      0.545455      0.545455
# 834         0.865350      0.545455      0.522727
# 643         0.864362      0.590909      0.522727
# 1687        0.859243      0.613636      0.500000

# %%
arg1_selected = result_all.sort_values('Rsquare_median',ascending=False)[0:10].index

# %% [markdown]
# # Plotting

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
#group by argu + opt and show the mean or median or the error
def plot_tune_result(arg1,arg2,error):
    output = result_all.groupby([arg1,arg2])['Rsquare_median'].aggregate([np.mean,np.median]).reset_index()
    #display(output)
    ax = sns.lineplot(x = arg1, y = error, 
                data = output, 
                hue= arg2,)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
    ax.set(xlabel='{}'.format(arg1), ylabel='Rsquare')
    plt.show()

# %%
plot_tune_result('argu','opt','median')

# %%
plot_tune_result('argu','class_weight','median')

# %%
plot_tune_result('argu','loss_fun','median')

# %%
plot_tune_result('argu','nl','median')

# %%
plot_tune_result('argu','epochs','median')

# %%
def plot_tune_result_3(arg1,arg2,arg3):
    output = result_all.groupby([arg1,arg2,arg3])['Rsquare_median'].aggregate([np.mean,np.median]).reset_index()
    
    #palette = sns.color_palette("rocket_r",n_color = )
    # Plot the lines on two facets
    ax = sns.relplot(
            data=output,
            x= arg1, y= 'mean',
            hue= arg2, col= arg3,
            kind="line",
            height=10, aspect=.75, facet_kws=dict(sharex=False),
    )
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
    ax.set(xlabel='{}'.format(arg1), ylabel='R_square')
    plt.show()

# %%
plot_tune_result_3('argu','class_weight','epochs')
# Out:
# No handles with labels found to put in legend.

# %%
plot_tune_result_3('argu','class_weight','loss_fun')
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Result Selection # =====# Result Selection # =====# Result Selection # =====# Result Selection # =====

# %% [markdown]
# # 1. Data Preparation

# %% [markdown]
# ## 1.1 Choose a Data Version

# %%
# 2nd Order Raw only!
test_coef = ["0","2","3","4","exponential"]
func_coef = ["raw","second","third","forth","exponential"]
for i in range(0,1):
    globals()[f'X{test_coef[i]}'],globals()[f'y{test_coef[i]}'],globals()[f'Y{test_coef[i]}'],globals()[f'X_Y_merged{test_coef[i]}'] = \
        eval(func_coef[i]+"_order_poly_fitting(all_metrics_df,testParamDf)")

version = '0' #raw ones
X,y,Y,X_Y_merged = eval('X'+version),eval('y'+version),eval('Y'+version),eval('X_Y_merged'+version)
objective = eval('objective_'+version)

# %% [markdown]
# ## 1.2 Models Construction

# %%
model_raw = battery_model(0,X,y,Y,X_Y_merged,objective)

# %% [markdown]
# ## 1.3 Data Argumentation

# %% [markdown]
# ### (Reset)

# %% [markdown]
# # 2. Training

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ```python
# index = 0
# for i0 in argu_all:
#     model_raw_copy1 = copy.deepcopy(model_raw)
#     model_raw_copy1.input_argumentation_update(i0)
#     model_raw_copy2 = copy.deepcopy(model_raw_copy1)
#     for i1 in loss_fun_all:
#         for i2 in class_weight_all:
#             for i3 in nl_all:
#                 for i4 in opt_all:
#                     for i5 in epochs_all:
#                         model_raw_copy = copy.deepcopy(model_raw_copy2)
#                         result['argu'][index] = i0
#                         result['loss_fun'][index] = i1
#                         result['class_weight'][index] = "{}".format(i2)
#                         result['nl'][index] = "{}".format(i3)
#                         result['opt'][index] = i4
#                         result['epochs'][index] = i5
#                         result['error'][index] = model_raw_copy.model_construction_and_training(all_metrics_df,i1,i2,i3,i4,i5,0)
#                         index+=1
#                         print (i0,i1,i2,i3,i4,i5)
# ```

# %% [markdown]
# # Result

# %%
model_raw_copy = copy.deepcopy(model_raw)

# %%
records = []
for i in arg1_selected:
    i0 = int(result_all['argu'][i])
    i1 = result_all['loss_fun'][i]
    i2 =eval(result_all['class_weight'][i])
    i3 = eval(result_all['nl'][i])
    i4 = result_all['opt'][i]
    i5 = int(result_all['epochs'][i])
    
    model_raw_copy1 = copy.deepcopy(model_raw_copy)
    model_raw_copy1.input_argumentation_update(i0)
    model_raw_copy2 = copy.deepcopy(model_raw_copy1)
    records.append(model_raw_copy2.model_construction_and_training('zscore',all_metrics_df,i1,i2,i3,i4,i5,0))
    plt.figure(i)
    model_raw_copy2.plot_curve("test",all_metrics_df,1000,2.5)
    plt.title("Here is the mode{}".format(i))
# Out:
# Metal device set to: Apple M1
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
#
# WARNING:tensorflow:From /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# 2021-11-28 23:00:32.686311: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2021-11-28 23:00:32.686790: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2021-11-28 23:00:32.858900: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-11-28 23:00:32.862046: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2021-11-28 23:00:33.002447: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 23:00:33.166716: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 23:00:39.740690: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 23:00:39.919576: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 23:00:40.039202: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 23:00:46.224297: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 23:00:46.410629: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 23:00:46.554420: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 23:00:53.807449: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 23:00:53.994840: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 23:00:54.142459: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 23:01:01.509809: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 23:01:01.691963: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 23:01:01.821897: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x2aedc3790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2021-11-28 23:01:14.430014: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 23:01:14.794992: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 23:01:14.935759: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x2a7e78ca0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2021-11-28 23:01:22.768014: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 23:01:22.965668: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 23:01:23.109964: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 23:01:40.980859: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 23:01:41.166121: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 23:01:41.302252: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 23:01:49.026215: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 23:01:49.208762: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 23:01:49.343524: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 23:02:06.019647: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 23:02:06.209054: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 23:02:06.346457: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 23:02:22.550180: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
model_raw_copy2.plot_curve("test_true",all_metrics_df,1000,2.5)

# %%
records_array = np.array(records)
select = arg1_selected[np.argsort(records_array) == 0][0]
display(result_all.loc[select])
#859 - Good
#770 not bad
#3825 overfitting / underfitting???
# 3881 -> WHen input dimension high (4) -> Hard to differeate those value -> tend to predict the same
# reject 4 dimension argument
# Out:
# Unnamed: 0                                 724
# argu                                       1.0
# loss_fun                                   mae
# class_weight    {0: 10000.0, 1: 100.0, 2: 1.0}
# nl                           [100, 80, 30, 10]
# opt                                       Adam
# epochs                                   200.0
# error                                72.875277
# Name: 724, dtype: object

# %%
i  = 287
i0 = int(result_all['argu'][i])
i1 = result_all['loss_fun'][i]
i2 =eval(result_all['class_weight'][i])
i3 = eval(result_all['nl'][i])
i4 = result_all['opt'][i]
i5 = int(result_all['epochs'][i])

model_raw_copy1 = copy.deepcopy(model_raw_copy)
model_raw_copy1.input_argumentation_update(i0)
model_raw_copy2 = copy.deepcopy(model_raw_copy1)
model_raw_copy2.model_construction_and_training('range',all_metrics_df,i1,i2,i3,i4,i5,0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/_w/m21mbpwj00q_0ghj07dwvwj80000gn/T/ipykernel_36812/1383499600.py in <module>
#       1 i  = 287
# ----> 2 i0 = int(result_all['argu'][i])
#       3 i1 = result_all['loss_fun'][i]
#       4 i2 =eval(result_all['class_weight'][i])
#       5 i3 = eval(result_all['nl'][i])
#
# NameError: name 'result_all' is not defined

# %%
model_raw_copy2.plot_curve("test",all_metrics_df,1000,2.5)

# %%
i  = 287
i0 = int(result_all['argu'][i])
i1 = result_all['loss_fun'][i]
i2 =eval(result_all['class_weight'][i])
i3 = eval(result_all['nl'][i])
i4 = result_all['opt'][i]
i5 = int(result_all['epochs'][i])

model_raw_copy1 = copy.deepcopy(model_raw_copy)
model_raw_copy1.input_argumentation_update(i0)
model_raw_copy2 = copy.deepcopy(model_raw_copy1)
model_raw_copy2.model_construction_and_training('range',all_metrics_df,i1,i2,i3,i4,i5,0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/_w/m21mbpwj00q_0ghj07dwvwj80000gn/T/ipykernel_36812/1383499600.py in <module>
#       1 i  = 287
# ----> 2 i0 = int(result_all['argu'][i])
#       3 i1 = result_all['loss_fun'][i]
#       4 i2 =eval(result_all['class_weight'][i])
#       5 i3 = eval(result_all['nl'][i])
#
# NameError: name 'result_all' is not defined

# %% [markdown]
# # Single Detection

# %%
i1 = 'mae'
i2 = {0: 100000000.0, 1: 10000.0, 2: 1.0}
i3 = [80,30,10]
i4 = 'Adam'
i5 = 250
model_raw_copy1 = copy.deepcopy(model_raw_copy)
model_raw_copy1.input_argumentation_update(1)
model_raw_copy2 = copy.deepcopy(model_raw_copy1)
model_raw_copy2.model_construction_and_training('range',all_metrics_df,i1,i2,i3,i4,i5,0)
# Out:
# 2021-11-28 19:25:39.012428: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 19:25:39.134772: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x2a2b87f70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2021-11-28 19:25:50.943857: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# [0.6276781980290913,
#  0.8816140479720855,
#  -4.944189354969369,
#  -2.1193241320895777,
#  0.9545952770372563,
#  -0.24062143372892075,
#  0.9509422191639261,
#  -17.525603056523238,
#  0.8794414693147818,
#  -2.6427463035383263,
#  0.29117512408101054,
#  0.4744851696501847,
#  0.9536353548633916,
#  0.6351458155157705,
#  -4.860292119406684,
#  -7.343661541662547,
#  0.772624604515847,
#  0.9642073753883109,
#  0.9592264049208372,
#  -0.886045291830329,
#  -168.98282260167937,
#  0.6495231315491904,
#  0.8211543157311063,
#  -227.3133167060608,
#  0.7115962197160709,
#  -0.42453426525621163,
#  0.5112580127454456,
#  -17.685701223204052,
#  0.190785780868588,
#  0.8984562724004819,
#  -38.22460639917443,
#  -60.757176169988846,
#  -1.4855780632931128,
#  0.19533564039494922,
#  0.998046431085355,
#  0.5698620967975029,
#  0.39768532866526796,
#  -5.279217047281014,
#  0.8700932876272107,
#  -0.4010098391140766,
#  0.14481394117391966,
#  -76123.00809289866,
#  0.9820225882541335,
#  0.9663720847876791]

# %%
R_square_1 = model_raw_copy2.error
np.median(R_square_1),np.mean(R_square_1),np.mean(np.array(R_square_1) > 0.8)
#(0.5554604469539068, -1632.7457611477657, 0.29545454545454547)
# Out:
# (0.5554604469539068, -1632.7457611477657, 0.29545454545454547)

# %%
i1 = 'mae'
i2 = {0: 2.0, 1: 1.0, 2: 1.0}
i3 = [80,30,10]
i4 = 'Adam'
i5 = 250
model_raw_copy1 = copy.deepcopy(model_raw_copy)
model_raw_copy1.input_argumentation_update(1)
model_raw_copy22 = copy.deepcopy(model_raw_copy1)
model_raw_copy22.model_construction_and_training('zscore',all_metrics_df,i1,i2,i3,i4,i5,0)
# Out:
# 2021-11-28 19:25:26.959937: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-11-28 19:25:27.080047: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x29633ec10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2021-11-28 19:25:38.620086: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# [-26.08657128987044,
#  0.9860780520472162,
#  -5.092535876405692,
#  0.9980433438226939,
#  0.5906065713200666,
#  -0.2532095831775387,
#  0.9361068925441749,
#  0.8309629990798857,
#  0.3231629321227246,
#  -0.36633945890826425,
#  0.9734782252369205,
#  0.993839230006853,
#  0.9325500042346964,
#  0.972576584901954,
#  0.5330607537439289,
#  -89.23218081532136,
#  -0.549699871615374,
#  0.7513342207198976,
#  0.9459534551568518,
#  0.9194200771565169,
#  -74.48909356958502,
#  0.9968818762517244,
#  -0.25744292671751334,
#  -13.969516574985802,
#  -10.648238559551734,
#  0.6420386814111908,
#  0.9777111058044958,
#  -7.7115529759371135,
#  0.9934642360549578,
#  0.994039601570634,
#  -3.008572048988902,
#  -58.67988495571588,
#  0.6577962561505812,
#  0.7747390263645477,
#  0.6486771480460624,
#  0.8831486145496354,
#  0.28603555968310623,
#  -28.3006001318485,
#  0.8913276730450173,
#  0.9548658373693152,
#  -0.547804572629722,
#  -56701.82559848229,
#  0.9812459285469929,
#  0.9432886244762141]

# %%
R_square_12 = model_raw_copy22.error
np.median(R_square_12),np.mean(R_square_12),np.mean(np.array(R_square_12) > 0.8)
# Out:
# (0.6424616381685537, -1213.1681557446261, 0.3181818181818182)

# %%
temp = []
for i in range(1,10):
    for k in range(1,5,2):
        if i <= 2:
            temp.append({0: i,
                        1: k,
                        2: 1})
        elif i%2==0:
            temp.append({0: i,
                        1: k,
                        2: 1})

# %%
temp
# Out:
# [{0: 1, 1: 1, 2: 1},
#  {0: 1, 1: 3, 2: 1},
#  {0: 2, 1: 1, 2: 1},
#  {0: 2, 1: 3, 2: 1},
#  {0: 4, 1: 1, 2: 1},
#  {0: 4, 1: 3, 2: 1},
#  {0: 6, 1: 1, 2: 1},
#  {0: 6, 1: 3, 2: 1},
#  {0: 8, 1: 1, 2: 1},
#  {0: 8, 1: 3, 2: 1}]

# %%
2%2
# Out:
# 0

# %%
model_raw_copy2.plot_curve("test",all_metrics_df,900,2.5)

# %%
model_raw_copy2.plot_curve("test_true",all_metrics_df,900,2.5)

# %%
argu_all = np.arange(1,3)

loss_fun_0 = 'mse'
loss_fun_1 = 'mae'
loss_fun_all = [loss_fun_0,loss_fun_1]

class_weight_all = []
for i in range(1,10):
    for k in range(1,5,2):
        if i <= 2:
            class_weight_all.append({0: i,
                                1: k,
                                2: 1})
        elif i%2==0:
            class_weight_all.append({0: i,
                                1: k,
                                2: 1})
nl_all = []
for i in range(10,101,30):
    for j in range(i+30,101,30):
        nl_all.append([j,i])
        for k in range(j+30,101,30):
            nl_all.append([k,j,i])
            for z in range(k+30,101,30):
                nl_all.append([z,k,j,i])
opt_all = ['Adam', 'RMSprop']
epochs_all = [150,300]
rows = len(argu_all)*len(loss_fun_all)*len(class_weight_all)*len(nl_all) *len(opt_all)*len(epochs_all)

# %%
import numpy as np
np.arange(1,3)
# Out:
# array([1, 2])

# %%
class_weight_all
# Out:
# [{0: 1, 1: 1, 2: 1},
#  {0: 1, 1: 3, 2: 1},
#  {0: 2, 1: 1, 2: 1},
#  {0: 2, 1: 3, 2: 1},
#  {0: 4, 1: 1, 2: 1},
#  {0: 4, 1: 3, 2: 1},
#  {0: 6, 1: 1, 2: 1},
#  {0: 6, 1: 3, 2: 1},
#  {0: 8, 1: 1, 2: 1},
#  {0: 8, 1: 3, 2: 1}]

# %%
nl_all
# Out:
# [[40, 10],
#  [70, 40, 10],
#  [100, 70, 40, 10],
#  [100, 40, 10],
#  [70, 10],
#  [100, 70, 10],
#  [100, 10],
#  [70, 40],
#  [100, 70, 40],
#  [100, 40],
#  [100, 70]]
